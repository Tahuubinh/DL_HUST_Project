# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./city_hour.csv/city_hour.csv')

# %%
data['City'].value_counts()
# Out:
# Ahmedabad             48192
# Delhi                 48192
# Mumbai                48192
# Bengaluru             48192
# Lucknow               48192
# Chennai               48192
# Hyderabad             48107
# Patna                 44554
# Gurugram              40258
# Visakhapatnam         35053
# Amritsar              29269
# Jorapokhar            28025
# Jaipur                26705
# Thiruvananthapuram    26651
# Amaravati             22784
# Brajrajnagar          22468
# Talcher               22161
# Kolkata               19503
# Guwahati              12002
# Coimbatore             9229
# Shillong               7402
# Chandigarh             7263
# Bhopal                 6903
# Kochi                  3854
# Ernakulam              3852
# Aizawl                 2680
# Name: City, dtype: int64

# %%
data_of_a_city = data[data['City'] == 'Delhi']

# %%
data_of_a_city
# Out:
#          City             Datetime   PM2.5    PM10      NO    NO2     NOx  \
# 245172  Delhi  2015-01-01 01:00:00  454.58  935.18   81.52  41.78  187.66
# 245173  Delhi  2015-01-01 02:00:00  440.44     NaN   70.80  43.46  176.83
# 245174  Delhi  2015-01-01 03:00:00  409.09     NaN  132.46  41.19  141.02
# 245175  Delhi  2015-01-01 04:00:00  436.12     NaN   84.78  39.55  102.84
# 245176  Delhi  2015-01-01 05:00:00  415.88  976.99   60.24  37.41   80.12
# ...       ...                  ...     ...     ...     ...    ...     ...
# 293359  Delhi  2020-06-30 20:00:00   43.19  123.26    6.33  22.28   17.66
# 293360  Delhi  2020-06-30 21:00:00   45.30  125.22    6.34  22.91   17.96
# 293361  Delhi  2020-06-30 22:00:00   49.04  129.39    6.29  20.95   16.80
# 293362  Delhi  2020-06-30 23:00:00   50.51  128.86    6.19  20.40   16.83
# 293363  Delhi  2020-07-01 00:00:00   54.01  128.66    6.33  21.05   16.81
#
#           NH3     CO    SO2     O3  Benzene  Toluene  Xylene    AQI  \
# ...

# %%
def getMaxNaNIndex(data, column):
    print(data[column].index[data[column].apply(np.isnan)].max())
for i in data_of_a_city.columns.tolist():
    if i == 'Datetime' or i == 'City':
        continue
    if i == 'AQI_Bucket':
        break
    print(f'{i}: ', end = '')
    getMaxNaNIndex(data_of_a_city, i)
# Out:
# PM2.5: 48160
# PM10: 48191
# NO: 48104
# NO2: 48104
# NOx: 48104
# NH3: 48191
# CO: 48105
# SO2: 48182
# O3: 48159
# Benzene: 48160
# Toluene: 48160
# Xylene: 48160
# AQI: 48121

# %%
def getMaxNaNIndex(data, column):
    print(data[column].index[data[column].apply(np.isnan)].max())
for i in data_of_a_city.columns.tolist():
    if i == 'Datetime' or i == 'City':
        continue
    if i == 'AQI_Bucket':
        break
    print(f'{i}: ', end = '')
    getMaxNaNIndex(data_of_a_city, i)

# %%
data_of_a_city = data[data['City'] == 'Ahmedabad']
for i in data_of_a_city.columns.tolist():
    print(f'{i}: ', end = '')
    print(data_of_a_city[i].isna().sum())
# Out:
# City: 0
# Datetime: 0
# PM2.5: 17063
# PM10: 39263
# NO: 16630
# NO2: 16155
# NOx: 15848
# NH3: 48192
# CO: 16630
# SO2: 19237
# O3: 19329
# Benzene: 13418
# Toluene: 13421
# Xylene: 13428
# AQI: 17271
# AQI_Bucket: 17271

# %%
data_of_a_city = data[data['City'] == 'Delhi']
for i in data_of_a_city.columns.tolist():
    print(f'{i}: ', end = '')
    print(data_of_a_city[i].isna().sum())
# Out:
# City: 0
# Datetime: 0
# PM2.5: 375
# PM10: 2421
# NO: 298
# NO2: 330
# NOx: 25
# NH3: 980
# CO: 364
# SO2: 2852
# O3: 2201
# Benzene: 38
# Toluene: 26
# Xylene: 18904
# AQI: 498
# AQI_Bucket: 498

# %%
data_of_a_city = data[data['City'] == 'Mumbai']
for i in data_of_a_city.columns.tolist():
    print(f'{i}: ', end = '')
    print(data_of_a_city[i].isna().sum())
# Out:
# City: 0
# Datetime: 0
# PM2.5: 30008
# PM10: 30797
# NO: 30593
# NO2: 30660
# NOx: 13139
# NH3: 38750
# CO: 1888
# SO2: 30024
# O3: 29927
# Benzene: 6531
# Toluene: 24780
# Xylene: 25127
# AQI: 30021
# AQI_Bucket: 30021

# %%
data_of_a_city = data[data['City'] == 'Bengaluru']
for i in data_of_a_city.columns.tolist():
    print(f'{i}: ', end = '')
    print(data_of_a_city[i].isna().sum())
# Out:
# City: 0
# Datetime: 0
# PM2.5: 4631
# PM10: 10987
# NO: 623
# NO2: 620
# NOx: 2088
# NH3: 7603
# CO: 4650
# SO2: 745
# O3: 5236
# Benzene: 10064
# Toluene: 7199
# Xylene: 48192
# AQI: 2695
# AQI_Bucket: 2695

# %%
data_of_a_city = data[data['City'] == 'Lucknow']
for i in data_of_a_city.columns.tolist():
    print(f'{i}: ', end = '')
    print(data_of_a_city[i].isna().sum())
# Out:
# City: 0
# Datetime: 0
# PM2.5: 3160
# PM10: 48192
# NO: 1342
# NO2: 1288
# NOx: 8756
# NH3: 25064
# CO: 8289
# SO2: 2637
# O3: 1361
# Benzene: 4305
# Toluene: 5309
# Xylene: 48192
# AQI: 3250
# AQI_Bucket: 3250

# %%
data_of_a_city = data[data['City'] == 'Chennai']
for i in data_of_a_city.columns.tolist():
    print(f'{i}: ', end = '')
    print(data_of_a_city[i].isna().sum())
# Out:
# City: 0
# Datetime: 0
# PM2.5: 3316
# PM10: 42383
# NO: 1239
# NO2: 1256
# NOx: 1193
# NH3: 12756
# CO: 1133
# SO2: 1283
# O3: 1809
# Benzene: 8997
# Toluene: 8858
# Xylene: 48192
# AQI: 3543
# AQI_Bucket: 3543

# %%
data_of_a_city = data[data['City'] == 'Hyderabad']
for i in data_of_a_city.columns.tolist():
    print(f'{i}: ', end = '')
    print(data_of_a_city[i].isna().sum())
# Out:
# City: 0
# Datetime: 0
# PM2.5: 3600
# PM10: 9521
# NO: 1413
# NO2: 1418
# NOx: 456
# NH3: 9712
# CO: 395
# SO2: 1854
# O3: 1488
# Benzene: 3431
# Toluene: 3577
# Xylene: 3577
# AQI: 3584
# AQI_Bucket: 3584

# %%
data_of_a_city
# Out:
#             City             Datetime  PM2.5    PM10    NO    NO2    NOx  NH3  \
# 0      Ahmedabad  2015-01-01 01:00:00    NaN     NaN  1.00  40.01  36.37  NaN
# 1      Ahmedabad  2015-01-01 02:00:00    NaN     NaN  0.02  27.75  19.73  NaN
# 2      Ahmedabad  2015-01-01 03:00:00    NaN     NaN  0.08  19.32  11.08  NaN
# 3      Ahmedabad  2015-01-01 04:00:00    NaN     NaN  0.30  16.45   9.20  NaN
# 4      Ahmedabad  2015-01-01 05:00:00    NaN     NaN  0.12  14.90   7.85  NaN
# ...          ...                  ...    ...     ...   ...    ...    ...  ...
# 48187  Ahmedabad  2020-06-30 20:00:00  42.92   98.36  2.79  84.27  43.19  NaN
# 48188  Ahmedabad  2020-06-30 21:00:00  44.41   88.17  4.28  56.44  30.73  NaN
# 48189  Ahmedabad  2020-06-30 22:00:00  33.68  202.79  4.42  37.66  21.67  NaN
# 48190  Ahmedabad  2020-06-30 23:00:00  56.86  222.73  3.77  29.78  17.34  NaN
# 48191  Ahmedabad  2020-07-01 00:00:00  37.63     NaN  4.42  35.04  20.17  NaN
#
# ...
