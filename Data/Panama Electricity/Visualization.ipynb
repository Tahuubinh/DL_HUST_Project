# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.dates as mdates

data = pd.read_csv('./continuous_dataset_preprocessing.csv')
matplotlib.style.use('ggplot')
figure(figsize=(6, 20))

# %%
data
# Out:
#              datetime  nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# 0       1/3/2015 1:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 1       1/3/2015 2:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2       1/3/2015 3:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 3       1/3/2015 4:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 4       1/3/2015 5:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...               ...         ...        ...       ...       ...        ...
# 43842  1/3/2020 19:00   1363.8664  26.686761  0.018390  0.003289  12.526505
# 43843  1/3/2020 20:00   1311.9671  26.318201  0.018259  0.001855  11.966489
# 43844  1/3/2020 21:00   1269.3826  26.048395  0.018068  0.001216  11.302663
# 43845  1/3/2020 22:00   1191.4653  25.819452  0.017854  0.000735  10.899143
# 43846  1/3/2020 23:00   1137.0714  25.604120  0.017678  0.000379  10.987437
#
# ...

# %%
df = data
df["datetime"] = df["datetime"].apply(pd.to_datetime)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
df = df.set_index('datetime')
df
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# 2015-01-03 06:00:00    879.2323  26.034143  0.019080  0.014542  20.062038
# 2015-01-03 07:00:00    932.4876  26.691492  0.019332  0.006645  21.623496
# 2015-01-03 08:00:00   1048.9720  27.674066  0.019370  0.006863  23.775317
# 2015-01-03 09:00:00   1167.9074  28.760400  0.019171  0.010231  24.636152
# 2015-01-03 10:00:00   1257.5069  29.766656  0.018759  0.009018  25.862671
#
#                        T2M_san  QV2M_san   TQL_san    W2M_san    T2M_dav  \
# datetime
# ...

# %%
df['new_index'] = [*range(5,15)]
df = df.set_index('new_index')
df
# Out:
#            nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc    T2M_san  \
# new_index
# 5            970.3450  25.865259  0.018576  0.016174  21.850546  23.482446
# 6            912.1755  25.899255  0.018653  0.016418  22.166944  23.399255
# 7            900.2688  25.937280  0.018768  0.015480  22.454911  23.343530
# 8            889.9538  25.957544  0.018890  0.016273  22.110481  23.238794
# 9            893.6865  25.973840  0.018981  0.017281  21.186089  23.075403
# 10           879.2323  26.034143  0.019080  0.014542  20.062038  22.995081
# 11           932.4876  26.691492  0.019332  0.006645  21.623496  24.285242
# 12          1048.9720  27.674066  0.019370  0.006863  23.775317  26.189691
# 13          1167.9074  28.760400  0.019171  0.010231  24.636152  27.916650
# 14          1257.5069  29.766656  0.018759  0.009018  25.862671  29.172906
#
#            QV2M_san   TQL_san    W2M_san    T2M_dav  QV2M_dav   TQL_dav  \
# new_index
# ...

# %%
df = data
df["datetime"] = df["datetime"].apply(pd.to_datetime)
df = df.set_index('datetime')
df
# Out:
#                      nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# datetime
# 2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
# ...                         ...        ...       ...       ...        ...
# 2020-01-03 19:00:00   1363.8664  26.686761  0.018390  0.003289  12.526505
# 2020-01-03 20:00:00   1311.9671  26.318201  0.018259  0.001855  11.966489
# 2020-01-03 21:00:00   1269.3826  26.048395  0.018068  0.001216  11.302663
# 2020-01-03 22:00:00   1191.4653  25.819452  0.017854  0.000735  10.899143
# 2020-01-03 23:00:00   1137.0714  25.604120  0.017678  0.000379  10.987437
#
# ...

# %%
data[data['datetime'] < '2019-01-03 19:00:00']
# Out:
#                  datetime  nat_demand    T2M_toc  QV2M_toc   TQL_toc  \
# 0     2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174
# 1     2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418
# 2     2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480
# 3     2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273
# 4     2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281
# ...                   ...         ...        ...       ...       ...
# 35077 2019-01-03 14:00:00   1531.8951  29.870264  0.017682  0.007311
# 35078 2019-01-03 15:00:00   1499.0103  29.640070  0.017560  0.012234
# 35079 2019-01-03 16:00:00   1412.5082  29.066125  0.017399  0.006636
# 35080 2019-01-03 17:00:00   1280.6772  28.129633  0.017390  0.001800
# 35081 2019-01-03 18:00:00   1312.7552  26.990503  0.017693  0.000995
#
#          W2M_toc    T2M_san  QV2M_san   TQL_san    W2M_san    T2M_dav  \
# ...

# %%
data
# Out:
#                  datetime  nat_demand    T2M_toc  QV2M_toc   TQL_toc  \
# 0     2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174
# 1     2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418
# 2     2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480
# 3     2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273
# 4     2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281
# ...                   ...         ...        ...       ...       ...
# 43842 2020-01-03 19:00:00   1363.8664  26.686761  0.018390  0.003289
# 43843 2020-01-03 20:00:00   1311.9671  26.318201  0.018259  0.001855
# 43844 2020-01-03 21:00:00   1269.3826  26.048395  0.018068  0.001216
# 43845 2020-01-03 22:00:00   1191.4653  25.819452  0.017854  0.000735
# 43846 2020-01-03 23:00:00   1137.0714  25.604120  0.017678  0.000379
#
#          W2M_toc    T2M_san  QV2M_san   TQL_san    W2M_san    T2M_dav  \
# ...

# %%
for i in data.columns.tolist():
    print(i)
# Out:
# datetime
# nat_demand
# T2M_toc
# QV2M_toc
# TQL_toc
# W2M_toc
# T2M_san
# QV2M_san
# TQL_san
# W2M_san
# T2M_dav
# QV2M_dav
# TQL_dav
# W2M_dav
# holiday
# school

# %%
for i in data.columns.tolist():
    if i == 'datetime':
        continue
    print(f'{i}: ', end = '')
    print(df[i].isna().sum())
# Out:
# nat_demand: 0
# T2M_toc: 0
# QV2M_toc: 0
# TQL_toc: 0
# W2M_toc: 0
# T2M_san: 0
# QV2M_san: 0
# TQL_san: 0
# W2M_san: 0
# T2M_dav: 0
# QV2M_dav: 0
# TQL_dav: 0
# W2M_dav: 0
# holiday: 0
# school: 0

# %%
for i, col in enumerate(df.columns):
    print(col)
# Out:
# nat_demand
# T2M_toc
# QV2M_toc
# TQL_toc
# W2M_toc
# T2M_san
# QV2M_san
# TQL_san
# W2M_san
# T2M_dav
# QV2M_dav
# TQL_dav
# W2M_dav
# holiday
# school

# %%
positions = [p for p in df.index
             if p.hour == 1
             and p.day == 3
             and p.month in range(1, 13, 3)]

for i, col in enumerate(df.columns):
    plt.figure(i)
    if col != 'nat_demand':
        ax = df[col].plot(rot=90, figsize=(15,5), x_compat = True)
    else:
        ax = df[col].plot(rot=90, figsize=(15,5), color = 'blue', x_compat = True)
    
    #ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.set_xticks(positions)
    ax.set_ylabel(col)
    plt.savefig(f'figs/{i}.png')
